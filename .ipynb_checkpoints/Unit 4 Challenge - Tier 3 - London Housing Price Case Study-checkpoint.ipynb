# %% [markdown]
# # Springboard Data Science Career Track Unit 4 Challenge - Tier 3 Complete
#
# ## Objectives
# Hey! Great job getting through those challenging DataCamp courses. You're learning a lot in a short span of time.
#
# In this notebook, you're going to apply the skills you've been learning, bridging the gap between the controlled environment of DataCamp and the *slightly* messier work that data scientists do with actual datasets!
#
# Here’s the mystery we’re going to solve: ***which boroughs of London have seen the greatest increase in housing prices, on average, over the last two decades?***
#
#
# A borough is just a fancy word for district. You may be familiar with the five boroughs of New York… well, there are 32 boroughs within Greater London [(here's some info for the curious)](https://en.wikipedia.org/wiki/London_boroughs). Some of them are more desirable areas to live in, and the data will reflect that with a greater rise in housing prices.
#
# ***This is the Tier 3 notebook, which means it's not filled in at all: we'll just give you the skeleton of a project, the brief and the data. It's up to you to play around with it and see what you can find out! Good luck! If you struggle, feel free to look at easier tiers for help; but try to dip in and out of them, as the more independent work you do, the better it is for your learning!***
#
# This challenge will make use of only what you learned in the following DataCamp courses:
# - Prework courses (Introduction to Python for Data Science, Intermediate Python for Data Science)
# - Data Types for Data Science
# - Python Data Science Toolbox (Part One)
# - pandas Foundations
# - Manipulating DataFrames with pandas
# - Merging DataFrames with pandas
#
# Of the tools, techniques and concepts in the above DataCamp courses, this challenge should require the application of the following:
# - **pandas**
#     - **data ingestion and inspection** (pandas Foundations, Module One)
#     - **exploratory data analysis** (pandas Foundations, Module Two)
#     - **tidying and cleaning** (Manipulating DataFrames with pandas, Module Three)
#     - **transforming DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **subsetting DataFrames with lists** (Manipulating DataFrames with pandas, Module One)
#     - **filtering DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **grouping data** (Manipulating DataFrames with pandas, Module Four)
#     - **melting data** (Manipulating DataFrames with pandas, Module Three)
#     - **advanced indexing** (Manipulating DataFrames with pandas, Module Four)
# - **matplotlib** (Intermediate Python for Data Science, Module One)
# - **fundamental data types** (Data Types for Data Science, Module One)
# - **dictionaries** (Intermediate Python for Data Science, Module Two)
# - **handling dates and times** (Data Types for Data Science, Module Four)
# - **function definition** (Python Data Science Toolbox - Part One, Module One)
# - **default arguments, variable length, and scope** (Python Data Science Toolbox - Part One, Module Two)
# - **lambda functions and error handling** (Python Data Science Toolbox - Part One, Module Four)

# %% [markdown]
# ## The Data Science Pipeline
#
# This is Tier Three, so we'll get you started. But after that, it's all in your hands! When you feel done with your investigations, look back over what you've accomplished, and prepare a quick presentation of your findings for the next mentor meeting.
#
# Data Science is magical. In this case study, you'll get to apply some complex machine learning algorithms. But as  [David Spiegelhalter](https://www.youtube.com/watch?v=oUs1uvsz0Ok) reminds us, there is no substitute for simply **taking a really, really good look at the data.** Sometimes, this is all we need to answer our question.
#
# Data Science projects generally adhere to the four stages of Data Science Pipeline:
# 1. Sourcing and loading
# 2. Cleaning, transforming, and visualizing
# 3. Modeling
# 4. Evaluating and concluding

# %% [markdown]
# ### 1. Sourcing and Loading
#
# Any Data Science project kicks off by importing  ***pandas***. The documentation of this wonderful library can be found [here](https://pandas.pydata.org/). As you've seen, pandas is conveniently connected to the [Numpy](http://www.numpy.org/) and [Matplotlib](https://matplotlib.org/) libraries.
#
# ***Hint:*** This part of the data science pipeline will test those skills you acquired in the pandas Foundations course, Module One.

# %% [markdown]
# #### 1.1. Importing Libraries

# %%
# Let's import the pandas, numpy libraries as pd, and np respectively. 
import pandas as pd
import numpy as np

# Load the pyplot collection of functions from matplotlib, as plt 
import matplotlib.pyplot as plt

#import datetime as dt

# %% [markdown]
# #### 1.2.  Loading the data
# Your data comes from the [London Datastore](https://data.london.gov.uk/): a free, open-source data-sharing portal for London-oriented datasets.

# %%
# First, make a variable called url_LondonHousePrices, and assign it the following link, enclosed in quotation-marks as a string:
# https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls

url_LondonHousePrices = "https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls"

# The dataset we're interested in contains the Average prices of the houses, and is actually on a particular sheet of the Excel file. 
# As a result, we need to specify the sheet name in the read_excel() method.
# Put this data into a variable called properties.  
properties = pd.read_excel(url_LondonHousePrices, sheet_name='Average price', index_col= None) #aka we're NOT setting an index, otherwise it will 0 index by default when we make a pandas dataframe

# %% [markdown]
# ### 2. Cleaning, transforming, and visualizing
# This second stage is arguably the most important part of any Data Science project. The first thing to do is take a proper look at the data. Cleaning forms the majority of this stage, and can be done both before or after Transformation.
#
# The end goal of data cleaning is to have tidy data. When data is tidy:
#
# 1. Each variable has a column.
# 2. Each observation forms a row.
#
# Keep the end goal in mind as you move through this process, every step will take you closer.
#
#
#
# ***Hint:*** This part of the data science pipeline should test those skills you acquired in:
# - Intermediate Python for data science, all modules.
# - pandas Foundations, all modules.
# - Manipulating DataFrames with pandas, all modules.
# - Data Types for Data Science, Module Four.
# - Python Data Science Toolbox - Part One, all modules

# %% [markdown]
# **2.1. Exploring your data**
#
# Think about your pandas functions for checking out a dataframe.

# %%
properties.head()
# Out:
#   Unnamed: 0 City of London Barking & Dagenham       Barnet       Bexley  \
# 0        NaT      E09000001          E09000002    E09000003    E09000004
# 1 1995-01-01    91448.98487         50460.2266  93284.51832  64958.09036
# 2 1995-02-01    82202.77314        51085.77983  93190.16963  64787.92069
# 3 1995-03-01    79120.70256        51268.96956  92247.52435  64367.49344
# 4 1995-04-01    77101.20804        53133.50526  90762.87492  64277.66881
#
#          Brent      Bromley       Camden      Croydon       Ealing  ...  \
# 0    E09000005    E09000006    E09000007    E09000008    E09000009  ...
# 1  71306.56698  81671.47692  120932.8881  69158.16225  79885.89069  ...
# 2  72022.26197  81657.55944  119508.8622  68951.09542  80897.06551  ...
# 3  72015.76274  81449.31143  120282.2131  68712.44341  81379.86288  ...
# 4  72965.63094  81124.41227   120097.899  68610.04641  82188.90498  ...
#
#     NORTH WEST YORKS & THE HUMBER EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND  \
# ...

# %% [markdown]
# **2.2. Cleaning the data**
#
# You might find you need to transpose your dataframe, check out what its row indexes are, and reset the index. You  also might find you need to assign the values of the first row to your column headings  . (Hint: recall the .columns feature of DataFrames, as well as the iloc[] method).
#
# Don't be afraid to use StackOverflow for help  with this.

# %%
properties = properties.transpose()
properties
# Out:
#                             0                    1                    2    \
# Unnamed: 0                  NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# City of London        E09000001          91448.98487          82202.77314
# Barking & Dagenham    E09000002           50460.2266          51085.77983
# Barnet                E09000003          93284.51832          93190.16963
# Bexley                E09000004          64958.09036          64787.92069
# Brent                 E09000005          71306.56698          72022.26197
# Bromley               E09000006          81671.47692          81657.55944
# Camden                E09000007          120932.8881          119508.8622
# Croydon               E09000008          69158.16225          68951.09542
# Ealing                E09000009          79885.89069          80897.06551
# Enfield               E09000010          72514.69096          73155.19746
# Greenwich             E09000011          62300.10169          60993.26863
# ...

# %%
properties.index
# Out:
# Index(['Unnamed: 0', 'City of London', 'Barking & Dagenham', 'Barnet',
#        'Bexley', 'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey', 'Harrow',
#        'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth', 'Lewisham',
#        'Merton', 'Newham', 'Redbridge', 'Richmond upon Thames', 'Southwark',
#        'Sutton', 'Tower Hamlets', 'Waltham Forest', 'Wandsworth',
#        'Westminster', 'Unnamed: 34', 'Inner London', 'Outer London',
#        'Unnamed: 37', 'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER',
#        'EAST MIDLANDS', 'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON',
#        'SOUTH EAST', 'SOUTH WEST', 'Unnamed: 47', 'England'],
#       dtype='object')

# %%
properties = properties.reset_index()
properties
# Out:
#                    index          0                    1                    2  \
# 0             Unnamed: 0        NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# 1         City of London  E09000001          91448.98487          82202.77314
# 2     Barking & Dagenham  E09000002           50460.2266          51085.77983
# 3                 Barnet  E09000003          93284.51832          93190.16963
# 4                 Bexley  E09000004          64958.09036          64787.92069
# 5                  Brent  E09000005          71306.56698          72022.26197
# 6                Bromley  E09000006          81671.47692          81657.55944
# 7                 Camden  E09000007          120932.8881          119508.8622
# 8                Croydon  E09000008          69158.16225          68951.09542
# 9                 Ealing  E09000009          79885.89069          80897.06551
# 10               Enfield  E09000010          72514.69096          73155.19746
# ...

# %%
properties.columns = properties.iloc[0] #could do properties[:1]?
properties
# Out:
# 0             Unnamed: 0        NaN  1995-01-01 00:00:00  1995-02-01 00:00:00  \
# 0             Unnamed: 0        NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# 1         City of London  E09000001          91448.98487          82202.77314
# 2     Barking & Dagenham  E09000002           50460.2266          51085.77983
# 3                 Barnet  E09000003          93284.51832          93190.16963
# 4                 Bexley  E09000004          64958.09036          64787.92069
# 5                  Brent  E09000005          71306.56698          72022.26197
# 6                Bromley  E09000006          81671.47692          81657.55944
# 7                 Camden  E09000007          120932.8881          119508.8622
# 8                Croydon  E09000008          69158.16225          68951.09542
# 9                 Ealing  E09000009          79885.89069          80897.06551
# 10               Enfield  E09000010          72514.69096          73155.19746
# ...

# %%
properties = properties[1:]
properties = properties.reset_index(drop=True)
properties
# Out:
# 0             Unnamed: 0        NaN 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 0         City of London  E09000001         91448.98487         82202.77314
# 1     Barking & Dagenham  E09000002          50460.2266         51085.77983
# 2                 Barnet  E09000003         93284.51832         93190.16963
# 3                 Bexley  E09000004         64958.09036         64787.92069
# 4                  Brent  E09000005         71306.56698         72022.26197
# 5                Bromley  E09000006         81671.47692         81657.55944
# 6                 Camden  E09000007         120932.8881         119508.8622
# 7                Croydon  E09000008         69158.16225         68951.09542
# 8                 Ealing  E09000009         79885.89069         80897.06551
# 9                Enfield  E09000010         72514.69096         73155.19746
# 10             Greenwich  E09000011         62300.10169         60993.26863
# ...

# %% [markdown]
# **2.3. Cleaning the data (part 2)**
#
# You might we have to **rename** a couple columns. How do you do this? The clue's pretty bold...

# %%
#old - worked:
properties.rename(columns={'Unnamed: 0':'Borough'}, inplace=True) #inplace will reassign original so you don't need to resave. otherwise would do properties = properties...
properties.columns = properties.columns.fillna('Post Code')
#suggested:
#properties.rename(columns={'Unnamed: 0':'Borough', pd.NaT: 'Post Code'})
#DOESN'T WORK TO CHANGE NaN! same issue I had with other methods. also why use NaT and not NaN? i know there is no pd.NaN
properties
# Out:
# 0                Borough  Post Code 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 0         City of London  E09000001         91448.98487         82202.77314
# 1     Barking & Dagenham  E09000002          50460.2266         51085.77983
# 2                 Barnet  E09000003         93284.51832         93190.16963
# 3                 Bexley  E09000004         64958.09036         64787.92069
# 4                  Brent  E09000005         71306.56698         72022.26197
# 5                Bromley  E09000006         81671.47692         81657.55944
# 6                 Camden  E09000007         120932.8881         119508.8622
# 7                Croydon  E09000008         69158.16225         68951.09542
# 8                 Ealing  E09000009         79885.89069         80897.06551
# 9                Enfield  E09000010         72514.69096         73155.19746
# 10             Greenwich  E09000011         62300.10169         60993.26863
# ...

# %% [markdown]
# **2.4.Transforming the data**
#
# Remember what Wes McKinney said about tidy data?
#
# You might need to **melt** your DataFrame here.

# %%
properties = properties.melt(id_vars=('Borough', 'Post Code'), var_name='Date', value_name='Avg House Price')
properties
# Out:
#                   Borough  Post Code       Date Avg House Price
# 0          City of London  E09000001 1995-01-01     91448.98487
# 1      Barking & Dagenham  E09000002 1995-01-01      50460.2266
# 2                  Barnet  E09000003 1995-01-01     93284.51832
# 3                  Bexley  E09000004 1995-01-01     64958.09036
# 4                   Brent  E09000005 1995-01-01     71306.56698
# ...                   ...        ...        ...             ...
# 15211              LONDON  E12000007 2021-05-01     497947.9589
# 15212          SOUTH EAST  E12000008 2021-05-01     350015.5072
# 15213          SOUTH WEST  E12000009 2021-05-01     277602.6983
# 15214         Unnamed: 47        NaN 2021-05-01             NaN
# 15215             England  E92000001 2021-05-01     271433.8707
#
# [15216 rows x 4 columns]

# %% [markdown]
# Remember to make sure your column data types are all correct. Average prices, for example, should be floating point numbers...

# %%
properties['Avg House Price'] = properties['Avg House Price'].apply(pd.to_numeric, errors='coerce') #use coerce and not ignore
properties

#tried this at first, but won't convert it to float64, stays as object
#properties['Avg House Price'] = properties['Avg House Price'].astype(float,errors='ignore')


#ways to control decimal places, disable scientific notation?
#should figure out how to reduce decimals and maybe display as currency (british pounds?)
# Out:
#                   Borough  Post Code       Date  Avg House Price
# 0          City of London  E09000001 1995-01-01      91448.98487
# 1      Barking & Dagenham  E09000002 1995-01-01      50460.22660
# 2                  Barnet  E09000003 1995-01-01      93284.51832
# 3                  Bexley  E09000004 1995-01-01      64958.09036
# 4                   Brent  E09000005 1995-01-01      71306.56698
# ...                   ...        ...        ...              ...
# 15211              LONDON  E12000007 2021-05-01     497947.95890
# 15212          SOUTH EAST  E12000008 2021-05-01     350015.50720
# 15213          SOUTH WEST  E12000009 2021-05-01     277602.69830
# 15214         Unnamed: 47        NaN 2021-05-01              NaN
# 15215             England  E92000001 2021-05-01     271433.87070
#
# [15216 rows x 4 columns]

# %%
properties.dtypes
# Out:
# Borough                    object
# Post Code                  object
# Date               datetime64[ns]
# Avg House Price           float64
# dtype: object

# %% [markdown]
# **2.5. Cleaning the data (part 3)**
#
# Do we have an equal number of observations in the ID, Average Price, Month, and London Borough columns? Remember that there are only 32 London Boroughs. How many entries do you have in that column?
#
# Check out the contents of the London Borough column, and if you find null values, get rid of them however you see fit.

# %%
properties.groupby('Borough').count()
#there are 317 dates and 32 boroughs, so we should expect there to be 317*32 = 10,144 rows (observations),
#but there are 15,216
#that's because there are things in the dataset that AREN'T boroughs, such as regional sum/total columns
#(we can see these things easily by looking at the original excel file) - these are the things in ALL CAPS,
#like NORTH EAST, and similarly things like 'Inner London' & 'Outer London' are not boroughs but groups that the boroughs
#are divided into. then of course there are the 'Unnamed' rows which represent the BLANK COLUMNS in the original excel file!
#3 blank columns were used to separate: the 32 Boroughs columns plus the 'City of London' which is NOT one of the 32 Boroughs,
#(City of London is E09000001 and then the 32 Boroughs are E09000002 thru E09000033)
#the 2 Inner/Outer subtotals, then 9 Regional subtotals and England overall. so including these 4 blank columns
#that's why there's 48 different rows ("Boroughs") (see next code block for counts): 32 + 1 + 3 + 2 + 9 + 1 = 48!
#so these 16 extra 'Boroughs' @ 317 rows each give us 5,072 extra rows we see in 15,216 over 10,144!
# Out:
#                       Post Code  Date  Avg House Price
# Borough
# Barking & Dagenham          317   317              317
# Barnet                      317   317              317
# Bexley                      317   317              317
# Brent                       317   317              317
# Bromley                     317   317              317
# Camden                      317   317              317
# City of London              317   317              317
# Croydon                     317   317              317
# EAST MIDLANDS               317   317              317
# EAST OF ENGLAND             317   317              317
# Ealing                      317   317              317
# Enfield                     317   317              317
# England                     317   317              317
# Greenwich                   317   317              317
# Hackney                     317   317              317
# Hammersmith & Fulham        317   317              317
# ...

# %%
properties.groupby('Borough').count().count()
# Out:
# Post Code          48
# Date               48
# Avg House Price    48
# dtype: int64

# %%
#so we don't need to delete the rows that aren't the 32 boroughs, but we do wanna delete the blanks/nulls due to the
#gap columns
#we can see from ^^above code block that the post code & avg price column shows nulls for all 3 blank/unnamed columns
#the reason it shows a date count even for the blank columns is that, the date is there/permanent, it's apart of our ID VARS!
#it's that IT HAS NO VALUES FILLED IN! which is why there's nothing actual for the column name, post code or avg house price
#remem the way melt works is that it'll have a id_var entry, so date in our case, for EVERY column, even if it's blank
#so if you look at the rows for the unnamed columns in our melted table, it's all NaNs!:

properties[properties['Borough']=='Unnamed: 47']
# Out:
#            Borough Post Code       Date  Avg House Price
# 46     Unnamed: 47       NaN 1995-01-01              NaN
# 94     Unnamed: 47       NaN 1995-02-01              NaN
# 142    Unnamed: 47       NaN 1995-03-01              NaN
# 190    Unnamed: 47       NaN 1995-04-01              NaN
# 238    Unnamed: 47       NaN 1995-05-01              NaN
# ...            ...       ...        ...              ...
# 15022  Unnamed: 47       NaN 2021-01-01              NaN
# 15070  Unnamed: 47       NaN 2021-02-01              NaN
# 15118  Unnamed: 47       NaN 2021-03-01              NaN
# 15166  Unnamed: 47       NaN 2021-04-01              NaN
# 15214  Unnamed: 47       NaN 2021-05-01              NaN
#
# [317 rows x 4 columns]

# %%
#delete rows w/ null values. so our 317*3 = 951 rows
properties = properties.dropna()
properties
# Out:
#                   Borough  Post Code       Date  Avg House Price
# 0          City of London  E09000001 1995-01-01      91448.98487
# 1      Barking & Dagenham  E09000002 1995-01-01      50460.22660
# 2                  Barnet  E09000003 1995-01-01      93284.51832
# 3                  Bexley  E09000004 1995-01-01      64958.09036
# 4                   Brent  E09000005 1995-01-01      71306.56698
# ...                   ...        ...        ...              ...
# 15210     EAST OF ENGLAND  E12000006 2021-05-01     310200.25640
# 15211              LONDON  E12000007 2021-05-01     497947.95890
# 15212          SOUTH EAST  E12000008 2021-05-01     350015.50720
# 15213          SOUTH WEST  E12000009 2021-05-01     277602.69830
# 15215             England  E92000001 2021-05-01     271433.87070
#
# [14265 rows x 4 columns]

# %%
#Remove remaining 13 non-boroughs!

nonBoroughs = ['City of London', 'Inner London', 'Outer London', 'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER',
               'EAST MIDLANDS', 'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON', 'SOUTH EAST', 'SOUTH WEST', 'England']
properties = properties[~properties['Borough'].isin(nonBoroughs)]

# %%
#Recheck the no. of boroughs so that it's 32
properties.groupby('Borough').count().count()
# Out:
# Post Code          32
# Date               32
# Avg House Price    32
# dtype: int64

# %% [markdown]
# **2.6. Visualizing the data**
#
# To visualize the data, why not subset on a particular London Borough? Maybe do a line plot of Month against Average Price?

# %%
#properties[properties['Borough']=='Bexley'].plot(x='Date',y='Avg House Price',kind='line')
#properties.plot(x='Date',y='Avg House Price',kind='line')
boroughs = properties.drop_duplicates(subset='Borough')['Borough']
[plt.plot(properties[properties['Borough']==borough]['Date'],properties[properties['Borough']==borough]['Avg House Price'], label=borough) for borough in boroughs]
plt.legend()
#Is there a way to make an INTERACTIVE graph in matplotlib, like w/ PowerBI or Tableau? Like where you can scroll over to see
#the values and ESP. WHICH LINE (BOROUGH) YOU'RE LOOKING AT cuz there's too many to be able to tell which colors are which /
#many very similar looking colors that can't distinguish
#One thing that would help slightly or atleast reduce noise is take out the ones that aren't actually boroughs
#can do interactive plots w/ plotly, or subplots

# %% [markdown]
# To limit the number of data points you have, you might want to extract the year from every month value your *Month* column.
#
# To this end, you *could* apply a ***lambda function***. Your logic could work as follows:
# 1. look through the `Month` column
# 2. extract the year from each individual value in that column
# 3. store that corresponding year as separate column.
#
# Whether you go ahead with this is up to you. Just so long as you answer our initial brief: which boroughs of London have seen the greatest house price increase, on average, over the past two decades?

# %%
#straight most to least expensive on last data point / at very end
properties_end_prices = properties[properties['Date']=='2021-05-01']
properties_end_prices.sort_values('Avg House Price', ascending=False).reset_index(drop=True, inplace=True)
properties_end_prices.index += 1
properties_end_prices
#You'll see that the ones that are the most expensive aren't necessarily the ones that had the biggest price INCREASE; maybe
#in absolute terms, but it's more valuable to look at relative terms, i.e. what boroughs increased by the most PERCENT. this
#can be done a couple different ways below
# Out:
#                  Borough  Post Code       Date  Avg House Price
# 1   Kensington & Chelsea  E09000020 2021-05-01     1.209210e+06
# 2            Westminster  E09000033 2021-05-01     9.745234e+05
# 3                 Camden  E09000007 2021-05-01     8.352650e+05
# 4   Hammersmith & Fulham  E09000013 2021-05-01     7.809439e+05
# 5   Richmond upon Thames  E09000027 2021-05-01     7.237749e+05
# 6              Islington  E09000019 2021-05-01     6.482634e+05
# 7             Wandsworth  E09000032 2021-05-01     6.254123e+05
# 8               Haringey  E09000014 2021-05-01     5.636872e+05
# 9                Hackney  E09000012 2021-05-01     5.530325e+05
# 10                Barnet  E09000003 2021-05-01     5.460823e+05
# 11               Lambeth  E09000022 2021-05-01     5.429730e+05
# 12                Merton  E09000024 2021-05-01     5.415041e+05
# 13             Southwark  E09000028 2021-05-01     5.287671e+05
# 14                Ealing  E09000009 2021-05-01     5.089070e+05
# ...

# %%
#the rank of avg price by borough at the START of the study, for comparison to the end^, above
properties_start_prices = properties[properties['Date']=='1995-01-01']
properties_start_prices.sort_values('Avg House Price', ascending=False).reset_index(drop=True, inplace=True)
properties_start_prices.index += 1
properties_start_prices
# Out:
#                  Borough  Post Code       Date  Avg House Price
# 1   Kensington & Chelsea  E09000020 1995-01-01     182694.83260
# 2            Westminster  E09000033 1995-01-01     133025.27720
# 3   Hammersmith & Fulham  E09000013 1995-01-01     124902.86020
# 4                 Camden  E09000007 1995-01-01     120932.88810
# 5   Richmond upon Thames  E09000027 1995-01-01     109326.12450
# 6                 Barnet  E09000003 1995-01-01      93284.51832
# 7              Islington  E09000019 1995-01-01      92516.48557
# 8             Wandsworth  E09000032 1995-01-01      88559.04381
# 9                 Harrow  E09000015 1995-01-01      84769.52599
# 10                Merton  E09000024 1995-01-01      82070.61330
# 11               Bromley  E09000006 1995-01-01      81671.47692
# 12  Kingston upon Thames  E09000021 1995-01-01      80875.84843
# 13                Ealing  E09000009 1995-01-01      79885.89069
# 14              Haringey  E09000014 1995-01-01      76287.56947
# ...

# %%
#rank at start and finish, side-by-side, with rank change
properties_start_prices = properties[properties['Date']=='1995-01-01']
properties_start_prices = properties_start_prices.sort_values('Avg House Price', ascending=False)
properties_start_prices['Rank']=range(1, 33)

properties_end_prices = properties[properties['Date']=='2021-05-01']
properties_end_prices = properties_end_prices.sort_values('Avg House Price', ascending=False)
properties_end_prices['Rank']=range(1, 33)

properties_startend_prices_ranked = properties_start_prices.merge(properties_end_prices, on='Borough', suffixes=('_1995', '_2021'))
properties_startend_prices_ranked['Rank Change'] = properties_startend_prices_ranked['Rank_1995'] - properties_startend_prices_ranked['Rank_2021']

properties_startend_prices_ranked.reset_index(drop=True, inplace=True)
properties_startend_prices_ranked.index += 1
#can't figure out why this isn't dropping the index?

#See how neighborhoods changed in rank, or not, over the time range
properties_startend_prices_ranked
# Out:
#                  Borough Post Code_1995  Date_1995  Avg House Price_1995  \
# 0   Kensington & Chelsea      E09000020 1995-01-01          182694.83260
# 1            Westminster      E09000033 1995-01-01          133025.27720
# 2   Hammersmith & Fulham      E09000013 1995-01-01          124902.86020
# 3                 Camden      E09000007 1995-01-01          120932.88810
# 4   Richmond upon Thames      E09000027 1995-01-01          109326.12450
# 5                 Barnet      E09000003 1995-01-01           93284.51832
# 6              Islington      E09000019 1995-01-01           92516.48557
# 7             Wandsworth      E09000032 1995-01-01           88559.04381
# 8                 Harrow      E09000015 1995-01-01           84769.52599
# 9                 Merton      E09000024 1995-01-01           82070.61330
# 10               Bromley      E09000006 1995-01-01           81671.47692
# 11  Kingston upon Thames      E09000021 1995-01-01           80875.84843
# ...

# %%
#See the neighborhoods change in rank from highest gaining to highest losing, as well as those in middle that were quite steady
properties_startend_prices_ranked.sort_values('Rank Change', ascending=False)
properties_startend_prices_ranked.reset_index(drop=True,inplace=True)
properties_startend_prices_ranked.index += 1
# Out:
#                  Borough Post Code_1995  Date_1995  Avg House Price_1995  \
# 27               Hackney      E09000012 1995-01-01           61296.52637
# 23               Lambeth      E09000022 1995-01-01           67770.98843
# 29         Tower Hamlets      E09000030 1995-01-01           59865.18995
# 26        Waltham Forest      E09000031 1995-01-01           61319.44913
# 22             Southwark      E09000028 1995-01-01           67885.20344
# 28              Lewisham      E09000023 1995-01-01           60491.26109
# 13              Haringey      E09000014 1995-01-01           76287.56947
# 19                 Brent      E09000005 1995-01-01           71306.56698
# 30                Newham      E09000025 1995-01-01           53539.31919
# 3                 Camden      E09000007 1995-01-01          120932.88810
# 6              Islington      E09000019 1995-01-01           92516.48557
# 7             Wandsworth      E09000032 1995-01-01           88559.04381
# ...

# %%
#See the neighborhoods that had the most dramatic change - for better OR for worse! - sorted by descending absolute value of change of rank 
properties_startend_prices_ranked['Abs Rank Change'] = abs(properties_startend_prices_ranked['Rank Change'])
properties_startend_prices_ranked.sort_values('Abs Rank Change', ascending=False).reset_index(drop=True, inplace=True)
properties_max.index += 1
# Out:
#                  Borough Post Code_1995  Date_1995  Avg House Price_1995  \
# 0                Hackney      E09000012 1995-01-01           61296.52637
# 1                Lambeth      E09000022 1995-01-01           67770.98843
# 2         Waltham Forest      E09000031 1995-01-01           61319.44913
# 3              Southwark      E09000028 1995-01-01           67885.20344
# 4                 Harrow      E09000015 1995-01-01           84769.52599
# 5          Tower Hamlets      E09000030 1995-01-01           59865.18995
# 6             Hillingdon      E09000017 1995-01-01           73834.82964
# 7                Croydon      E09000008 1995-01-01           69158.16225
# 8                Enfield      E09000010 1995-01-01           72514.69096
# 9                 Sutton      E09000029 1995-01-01           71536.97357
# 10              Havering      E09000016 1995-01-01           68000.13774
# 11               Bromley      E09000006 1995-01-01           81671.47692
# ...

# %%
#most to least maximum prices reached in the time range
#this is basically the same list as above, going by end-value

properties_max = properties.groupby('Borough')['Avg House Price'].max()
properties_max = pd.DataFrame(properties_max, columns=['Avg House Price'])
properties_max = properties_max.sort_values('Avg House Price', ascending=False)
#properties_max.index += 1  >> can't do this here bc w/ groupby, index is the borough strings, but would want to add a
#column to left of index / another/higher index level if possible to show rank
properties_max
# Out:
#                       Avg House Price
# Borough
# Kensington & Chelsea     1.463378e+06
# Westminster              1.117408e+06
# Camden                   8.902884e+05
# Hammersmith & Fulham     7.811750e+05
# Richmond upon Thames     7.237749e+05
# Islington                6.959130e+05
# Wandsworth               6.338261e+05
# Hackney                  6.071497e+05
# Haringey                 5.904514e+05
# Merton                   5.579119e+05
# Barnet                   5.494012e+05
# Lambeth                  5.448445e+05
# Southwark                5.440097e+05
# Brent                    5.222393e+05
# Kingston upon Thames     5.112600e+05
# Ealing                   5.089070e+05
# Harrow                   4.891035e+05
# Waltham Forest           4.871331e+05
# Tower Hamlets            4.869225e+05
# Bromley                  4.859468e+05
# Redbridge                4.525041e+05
# Lewisham                 4.493226e+05
# Hounslow                 4.420227e+05
# ...

# %%
#biggest to least price differentials between max and min price over time range, by borough
#still the same group as above 2
properties_maxmin = properties.groupby('Borough')['Avg House Price'].agg([min,max])
properties_maxmin['price_increase'] = properties_maxmin['max'] - properties_maxmin['min']
properties_maxmin = properties_maxmin.sort_values('price_increase', ascending=False)
properties_maxmin
# Out:
#                                min           max  price_increase
# Borough
# Kensington & Chelsea  182345.24630  1.463378e+06    1.281033e+06
# Westminster           131468.30960  1.117408e+06    9.859392e+05
# Camden                115418.83960  8.902884e+05    7.748696e+05
# Hammersmith & Fulham  120635.94670  7.811750e+05    6.605391e+05
# Richmond upon Thames  106875.00000  7.237749e+05    6.168999e+05
# Islington              89406.19881  6.959130e+05    6.065068e+05
# Wandsworth             86518.05945  6.338261e+05    5.473080e+05
# Hackney                61296.52637  6.071497e+05    5.458532e+05
# Haringey               76287.56947  5.904514e+05    5.141639e+05
# Southwark              60885.98483  5.440097e+05    4.831238e+05
# Lambeth                65381.51908  5.448445e+05    4.794630e+05
# Merton                 79569.22895  5.579119e+05    4.783427e+05
# Barnet                 90107.23471  5.494012e+05    4.592939e+05
# ...

# %%
#biggest to least price differentials from first to last measurement of avg price in the time range, by borough
#again same group
properties_start_prices = properties[properties['Date']=='1995-01-01'] #could've done Date minimum /
properties_end_prices = properties[properties['Date']=='2021-05-01']   #maximum?
properties_price_change_startend = properties_end_prices.merge(properties_start_prices, on='Borough', suffixes=('_2021','_1995'))
properties_price_change_startend['price_change'] = properties_price_change_startend['Avg House Price_2021'] - properties_price_change_startend['Avg House Price_1995']
properties_price_change_startend = properties_price_change_startend.sort_values('price_change', ascending=False).reset_index(drop=True)
properties_price_change_startend.index += 1
properties_price_change_startend
# Out:
#                  Borough Post Code_2021  Date_2021  Avg House Price_2021  \
# 1   Kensington & Chelsea      E09000020 2021-05-01          1.209210e+06
# 2            Westminster      E09000033 2021-05-01          9.745234e+05
# 3                 Camden      E09000007 2021-05-01          8.352650e+05
# 4   Hammersmith & Fulham      E09000013 2021-05-01          7.809439e+05
# 5   Richmond upon Thames      E09000027 2021-05-01          7.237749e+05
# 6              Islington      E09000019 2021-05-01          6.482634e+05
# 7             Wandsworth      E09000032 2021-05-01          6.254123e+05
# 8                Hackney      E09000012 2021-05-01          5.530325e+05
# 9               Haringey      E09000014 2021-05-01          5.636872e+05
# 10               Lambeth      E09000022 2021-05-01          5.429730e+05
# 11             Southwark      E09000028 2021-05-01          5.287671e+05
# 12                Merton      E09000024 2021-05-01          5.415041e+05
# ...

# %%
#PERCENT increase in least price to highest price of each borough over time period, from greatest %increase to least
properties_maxmin_pct = properties.groupby('Borough')['Avg House Price'].agg([min,max])
properties_maxmin_pct['percent_increase'] = ((properties_maxmin_pct['max'] - properties_maxmin_pct['min']) / properties_maxmin_pct['min']) * 100
properties_maxmin_pct.sort_values('percent_increase', ascending=False)

properties_startend_ranks = properties_startend_prices_ranked[['Borough', 'Rank_1995', 'Rank_2021']]
properties_maxmin_pct = properties_maxmin_pct.merge(properties_startend_ranks, on='Borough')
properties_maxmin_pct['Rank Change'] = properties_maxmin_pct['Rank_1995'] - properties_maxmin_pct['Rank_2021']
properties_maxmin_pct = properties_maxmin_pct.sort_values('percent_increase', ascending=False).reset_index(drop=True)
properties_maxmin_pct.index += 1
properties_maxmin_pct
# Out:
#                  Borough           min           max  percent_increase  \
# 1                Hackney   61296.52637  6.071497e+05        890.512471
# 2              Southwark   60885.98483  5.440097e+05        793.489283
# 3            Westminster  131468.30960  1.117408e+06        749.944392
# 4                Lambeth   65381.51908  5.448445e+05        733.331037
# 5          Tower Hamlets   59865.18995  4.869225e+05        713.364961
# 6         Waltham Forest   60252.12246  4.871331e+05        708.491206
# 7   Kensington & Chelsea  182345.24630  1.463378e+06        702.531435
# 8               Lewisham   57700.33538  4.493226e+05        678.717432
# 9              Islington   89406.19881  6.959130e+05        678.372213
# 10              Haringey   76287.56947  5.904514e+05        673.981166
# 11                Camden  115418.83960  8.902884e+05        671.354493
# 12                Newham   53153.88306  3.910879e+05        635.765446
# ...

# %%
#percent increase over time period (from first measurement to last) from greatest to least, by borough
properties_start_prices = properties[properties['Date']=='1995-01-01'] #could've done Date minimum /
properties_end_prices = properties[properties['Date']=='2021-05-01']   #maximum?
properties_price_change_startend = properties_start_prices.merge(properties_end_prices, on='Borough', suffixes=('_1995','_2021'))
properties_price_change_startend['price_change'] = properties_price_change_startend['Avg House Price_2021'] - properties_price_change_startend['Avg House Price_1995']
#properties_price_change_startend.sort_values('price_change', ascending=False)
properties_price_change_startend['percent_increase'] = ((properties_price_change_startend['Avg House Price_1995'] - properties_price_change_startend['Avg House Price_2021']) / properties_price_change_startend['Avg House Price_2021']) * 100
properties_price_change_startend = properties_price_change_startend.merge(properties_startend_ranks, on='Borough')
properties_price_change_startend = properties_price_change_startend.sort_values('percent_increase', ascending=False).reset_index(drop=True)
properties_price_change_startend.index += 1
properties_price_change_startend
# Out:
#                  Borough Post Code_1995  Date_1995  Avg House Price_1995  \
# 1                 Sutton      E09000029 1995-01-01           71536.97357
# 2                Croydon      E09000008 1995-01-01           69158.16225
# 3                 Harrow      E09000015 1995-01-01           84769.52599
# 4                 Bexley      E09000004 1995-01-01           64958.09036
# 5               Havering      E09000016 1995-01-01           68000.13774
# 6                Enfield      E09000010 1995-01-01           72514.69096
# 7                 Barnet      E09000003 1995-01-01           93284.51832
# 8             Hillingdon      E09000017 1995-01-01           73834.82964
# 9                Bromley      E09000006 1995-01-01           81671.47692
# 10    Barking & Dagenham      E09000002 1995-01-01           50460.22660
# 11              Hounslow      E09000018 1995-01-01           72231.70537
# 12             Redbridge      E09000026 1995-01-01           72189.58437
# ...

# %%
#I used 2 slightly different measures to determine the average increase in housing prices in the London boroughs


#If we go on the basis of percent increase from the minimum to the maximum average price over the timespan
#the City of London has by far the largest increase of over 1,100%! Following that,
#Hackney, Southwark, Westminster, Lambeth, Tower Hamlets, Waltham Forest and Kensington & Chelsea rounding out the top 7,
#in that order, which each increased over 700%!
#properties_maxmin.sort_values('percent_increase', ascending=False).head(8)



#If we go on the basis of percent increase from the first average housing price measurement/date to the last, it is almost
#the exact same group, but in a slightly different order:
#Hackney had the overall highest increase with over 800%! The City of London was the second highest overall, and the
#remaining 6 for the top 7 boroughs are:
#Lambeth, Waltham Forest, Tower Hamlets, Southwark, Haringey and Westminster, which each increased over 630%! 
#properties_price_change_startend.sort_values('percent_increase', ascending=False).head(8)

# %% [markdown]
# **3. Modeling**
#
# Consider creating a function that will calculate a ratio of house prices, comparing the price of a house in 2018 to the price in 1998.
#
# Consider calling this function create_price_ratio.
#
# You'd want this function to:
# 1. Take a filter of dfg, specifically where this filter constrains the London_Borough, as an argument. For example, one admissible argument should be: dfg[dfg['London_Borough']=='Camden'].
# 2. Get the Average Price for that Borough, for the years 1998 and 2018.
# 4. Calculate the ratio of the Average Price for 1998 divided by the Average Price for 2018.
# 5. Return that ratio.
#
# Once you've written this function, you ultimately want to use it to iterate through all the unique London_Boroughs and work out the ratio capturing the difference of house prices between 1998 and 2018.
#
# Bear in mind: you don't have to write a function like this if you don't want to. If you can solve the brief otherwise, then great!
#
# ***Hint***: This section should test the skills you acquired in:
# - Python Data Science Toolbox - Part One, all modules

# %%
#summary of above/beginning needed to run this, in case code execution times out i.e. doesn't recognize variables, just rerun this script / run this block w/ this script 
# import pandas as pd
# import numpy as np
# import datetime as dt

# url_LondonHousePrices = "https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls"
# properties = pd.read_excel(url_LondonHousePrices, sheet_name='Average price', index_col= None)
# properties = properties.transpose()
# properties = properties.reset_index()
# properties.columns = properties.iloc[0]
# properties = properties[1:]
# properties = properties.reset_index(drop=True)
# properties.rename(columns={'Unnamed: 0':'Borough'}, inplace=True)
# properties.columns = properties.columns.fillna('Post Code')
# properties = properties.melt(id_vars=('Borough', 'Post Code'), var_name='Date', value_name='Avg House Price')
# properties['Avg House Price'] = properties['Avg House Price'].apply(pd.to_numeric)
# properties = properties.dropna()

#boroughs = properties.drop_duplicates(subset='Borough')['Borough']

import datetime as dt

#class create_price_ratio:  #don't need to make a class
def create_price_ratio(dataframe): #if leaving out class, then instead of init, just name it function, & don't need 'self'
    dataframe = dataframe   #removed 'self.' only need if making a class
    price_ratios = []
    for borough in boroughs: 
        avg1998price = dataframe[(dataframe['Borough']==borough) & (dataframe['Date'].dt.year==1998)]['Avg House Price'].mean()
        avg2018price = dataframe[(dataframe['Borough']==borough) & (dataframe['Date'].dt.year==2018)]['Avg House Price'].mean()
        price_ratio_1998_2018 = avg1998price/avg2018price #it makes alot more intuitive sense to do other way around to show increase ratio, but they ask for it like this so
        price_ratios.append([borough, avg1998price, avg2018price, price_ratio_1998_2018])
        price_ratios_df = pd.DataFrame(price_ratios, columns=['Borough', 'Avg Price 1998', 'Avg Price 2018', 'Price Ratio_1998_to_2018'])   #removed 'self.'
        
    price_ratios_df = price_ratios_df.sort_values('Price Ratio_1998_to_2018').reset_index(drop=True) #removed '.self'
    price_ratios_df.index += 1
    print(price_ratios_df) #for some reason leaving it alone doesn't print here?
    
    
create_price_ratio(properties)
        
#could do inside out, put function inside of for-loop and keep function smaller and put rest outside at end / call:
#so then you're basically calling the function to run/compute those 3 calculations and store them as a triplet/row in the series
#then at end convert that appended series to a dataframe and sort to taste

#price_ratios = []

#def create_price_ratio(dataframe): #if leaving out class, then instead of init, just name it function
#     dataframe = dataframe
#     avg1998price = dataframe[(dataframe['Borough']==borough) & (dataframe['Date'].dt.year==1998)]['Avg House Price'].mean()
#     avg2018price = dataframe[(dataframe['Borough']==borough) & (dataframe['Date'].dt.year==2018)]['Avg House Price'].mean()
#     price_ratio_2018_1998 = avg2018price/avg1998price
#     price_ratios.append([borough, avg1998price, avg2018price, price_ratio_2018_1998])

# for borough in boroughs:
#     create_price_ratio(properties)

# price_ratios_df = pd.DataFrame(price_ratios, columns=['Borough', 'Avg Price 1998', 'Avg Price 2018', 'Price Ratio'])
# price_ratios_df = price_ratios_df.sort_values('Price Ratio', ascending=False).reset_index(drop=True)
# price_ratios_df.index += 1

#or could loop thru the boroughs where the function just references the borough and the properties df is outside of / before that
# Out:
#                  Borough  Avg Price 1998  Avg Price 2018  \
# 1                Hackney    87869.535804    5.446405e+05
# 2         Waltham Forest    75557.474132    4.408594e+05
# 3              Southwark    91405.187779    5.042354e+05
# 4               Lewisham    75539.051649    4.116290e+05
# 5            Westminster   190531.949942    1.020025e+06
# 6                 Newham    67671.270763    3.590225e+05
# 7               Haringey   107419.850108    5.515606e+05
# 8   Kensington & Chelsea   268350.122142    1.363880e+06
# 9                Lambeth   103179.118943    5.115364e+05
# 10                Camden   170688.973933    8.424104e+05
# 11    Barking & Dagenham    60285.821083    2.951967e+05
# 12                 Brent   100692.590417    4.928454e+05
# 13             Islington   134148.973300    6.498241e+05
# 14             Greenwich    81532.933366    3.883443e+05
# 15            Wandsworth   125406.807233    5.966491e+05
# ...

# %% [markdown]
# ### 4. Conclusion
# What can you conclude? Type out your conclusion below.
#
# Look back at your notebook. Think about how you might summarize what you have done, and prepare a quick presentation on it to your mentor at your next meeting.
#
# We hope you enjoyed this practical project. It should have consolidated your data hygiene and pandas skills by looking at a real-world problem involving just the kind of dataset you might encounter as a budding data scientist. Congratulations, and looking forward to seeing you at the next step in the course!

# %%
#It seems that the boroughs with the steepest increase in housing prices were the ones nearest to the city center, i.e.
#The City of London itself, and the ones with less stark price hikes tended to be further away
#make a plot of price increase vs. distance from borough-center to city-center and should see an inversely proportional trend
